# %%
import numpy as np
from decimal import *

# %%
getcontext().prec = 50
n=50

s=[]
for i in range (n+1):
    d = Decimal(1)/Decimal(3.0**i)
    print d
    s.append(d)
    
print 'somatorio',sum(s)
# Out:
# 1
# 0.33333333333333333333333333333333333333333333333333
# 0.11111111111111111111111111111111111111111111111111
# 0.037037037037037037037037037037037037037037037037037
# 0.012345679012345679012345679012345679012345679012346
# 0.0041152263374485596707818930041152263374485596707819
# 0.0013717421124828532235939643347050754458161865569273
# 0.00045724737082761774119798811156835848193872885230910
# 0.00015241579027587258039932937052278616064624295076970
# 0.000050805263425290860133109790174262053548747650256567
# 0.000016935087808430286711036596724754017849582550085522
# 0.0000056450292694767622370121989082513392831941833618407
# 0.0000018816764231589207456707329694171130943980611206136
# 6.2722547438630691522357765647237103146602037353786E-7
# 2.0907515812876897174119255215745701048867345784595E-7
# 6.9691719376256323913730850719152336829557819281984E-8
# 2.3230573125418774637910283573050778943185939760661E-8
# 7.7435243751395915459700945243502596477286465868871E-9
# ...

# %%
a = 3.0/2.0  # = sum(1/3**n)
print a
# Out:
# 1.5

# %%
x = 4.0/3.0  # = sum(1/4**n)
print x
# Out:
# 1.33333333333

# %%
y = 5.0/4.0  # = sum(1/5**n)
print y
# Out:
# 1.25

# %%
z = 6.0/5.0 # = sum(1/6**n)
print z
# Out:
# 1.2

# %%
w = 7.0/6.0 # = sum(1/7**n)
print w
# Out:
# 1.16666666667
