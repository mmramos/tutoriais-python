# %% [markdown]
# <div style="background-color: #E0EEEE; height: 1500px"> <!--DIV FUNDO-->
# <div style="font-family: Times; color: white; height: 25px; background-color: #4682B4"> <!--DIV BARRA SUPERIOR-->
# <center>UHAUHAUHAHUA</center></div>
# <!--Banner Azul-->
# <br>
# <div id="2" style="border: 1px solid black; color: black; width: 46%; height: 5%; background-color: #FF0000; margin-left: 28%; float: center">
# <center><p>HSAHUISAHUISAIUHSI</p></center>
# </div>
# <br>
#
# <!--Div da esquerda-->
# <div id="31" style="width: 28%; height: 60%; background-color: #a2d9ce; margin-left: 2%; float: left; padding: 0.2%"></div>
#
# <!--Div do centro-->
# <div id="32" style="left: 30%; top: 53%; width: 40%; height: 60%; background-color:  #f7dc6f; margin-left: 1.5%; float: right">
# </div>
#
# <!--Div da direita-->
# <div id="33" style="height: 80%; width: 25%;font-size: 11pt; background-color: #FF0000; margin-right: 2%; float: right"></div>
#
# <!--Div da esquerda abaixo linha-->
# <div id="32" style="left: 2%; top: 50%; width: 69%; height: 2.5%; background-color: #FF0000; margin-left: 2%; margin-top: 1.5%; float: left">
# </div>
#
# <!--Div da esquerda abaixo esquerda -->
# <div id="31" style="width: 28%; height: 20%; background-color: #FF0000; margin-left: 2%; margin-top: 2%; float: left; padding: 0.2%"></div>
#
# <!--Div da esquerda abaixo centro -->
# <div id="31" style="font-size: 11pt; width: 38%; height: 20%; background-color: #FF0000; margin-left: 2%; margin-top: 2%; float: left; padding: 0.2%"></div>
#
# </div> <!--Div final-->

# %% [markdown]
# <div style="background-color: #E0EEEE; height: 1500px"> <!--DIV FUNDO-->
# <div style="font-family: Times; font-size: 13pt; color: white; height: 23px; background-color: #4682B4"> <!--DIV BARRA SUPERIOR-->
# <center>Institucional | Editais e licitações | Serviços | Pesquisa | Produção Científica | Biblioteca | Divulgação Científica | Pessoal</center></div>
# <!--Banner Azul-->
# <br>
# <div id="2" style="border: 1px solid black; color: black; width: 46%; height: 5%; background-color: #4169E1; margin-left: 28%; float: center">
# <center><p></p></center>
# </div>
# <br>
#
# <!--Div da esquerda-->
# <div id="31" style="width: 28%; height: 40.8%; margin-left: 2%; float: left">
# <div style="font-family: Times; color: white;font-size: 13pt; background-color: #9FB6CD"><center>Acesso à Informação</center></div>
# <!----------------------------Tudo que está dentro de "acesso a informação"-------------------------------------->
#
# <div style="font-family: Arial; font-size: 12pt; background-color: #B9D3EE; height: 39%">
#
# Institucional
# <br>Ações e programas
# <br>Auditorias
# <br>Convênios
# <br>Despesas
# <br>Licitações e contratos
# <br>Servidores
# <br>Perguntas frequentes
# <br>Sobre a Lei de Acesso à Informação
# <br>Plano de Logística Sustentável
# <br>Serviço de Informação ao Cidadão - SIC
# <br>Informações classificadas
#
# </div>
#
# <div style="font-family: Times; color: white;font-size: 13pt; background-color: #9FB6CD; margin-top: 6%"><center>Projetos Estruturantes</center></div>
#
# <div style="font-family: Arial; font-size: 12pt; background-color: #B9D3EE">
# <img src='http://www.on.br/conteudo/proj_estruturantes/logos/logo_astrosoft.jpg' style="width: 20%; height: 20%"><img src='http://www.on.br/conteudo/proj_estruturantes/logos/logo_plataforma.jpg' style="width: 20%; height: 20%"><img src='http://www.on.br/conteudo/proj_estruturantes/logos/paubrasil.jpg' style="width: 20%; height: 20%"><img src='http://www.on.br/conteudo/proj_estruturantes/logos/logo_impacton.jpg' style="width: 20%; height: 20%">
#
#
# </div>
#
# <!--------------------------------------------------------------------------------------------------------------->
# </div>
#
# <!--Div do centro-->
# <div id="32" style="left: 30%; top: 53%; width: 39%; height: 40.8%; margin-left: 1.5%; float: left">
# <div style="font-family: Times; color: white;font-size: 13pt; background-color: #9FB6CD"><center>Notícias</center></div>
#
#
# <!---------------------------------------Tudo que está dentro de "Notícias"-------------------------------------->
# <div style="font-family: Arial; overflow: auto; font-size: 12pt; background-color: #B9D3EE; height: 39%">
#
# 12/01/2015<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/Segundos2015.html" target="_blank"><b>Ano de 2015 terá um segundo a mais</b></a><br>
#
# <!--------------------------------------------------------------Notícias------------------------------------------------->
# 			<font color="#CFCFCF">----------------------------------------</font><br>09/01/2015<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/lancaanuario.html" target="_blank"><b>Anuário do Observatório Nacional 2015 está disponível</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>08/01/2015<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/acordoon.html" target="_blank"><b>ON e MAST assinam acordo de cooperação</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>19/12/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/verao.html" target="_blank"><b>Verão começa às 21h03 do dia 21 de dezembro</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>16/12/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/patente.html" target="_blank"><b>Observatório Nacional deposita pedido de patente no INPI</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>11/12/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/capes.html" target="_blank"><b>Pesquisador do ON recebe Grande Prêmio de Melhor Tese CAPES 2014</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>09/12/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/eletronicos.html" target="_blank"><b>Observatório Nacional Disponibiliza validador de Documentos Eletrônicos</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>03/12/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/gestao.html" target="_blank"><b>Sistema de Gestão da Qualidade da DSHO-ON foi reaprovado pelo Inter-American Metrology System (SIM), para manutenção de seu reconhecimento internacional (MRA).</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>25/11/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/estudantes.html" target="_blank"><b>Estudantes provocam Terremoto em Madureira</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>24/11/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/morte.html" target="_blank"><b>Morre Paulo Mourilhe Silva, ex-chefe da Divisão Serviço da Hora</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>24/11/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/camara.html" target="_blank"><b>Comissão da Câmara Federal aprova 2 de dezembro como Dia da Astronomia</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>19/11/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/pesquis.html" target="_blank"><b>Pesquisadores do ON são contemplados com recursos do CNPq</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>14/11/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/cientista.html" target="_blank"><b>Pesquisadores do ON são contemplados no programa Cientista do Nosso Estado 2014, da FAPERJ</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>06/11/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/parceria.html" target="_blank"><b>Observatório Nacional faz parceria com grupo experimental francês</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>05/11/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/portal.html" target="_blank"><b>Novo portal divulga dados sismográficos em tempo real</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>04/11/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/premiacao.html" target="_blank"><b>Pesquisador do ON é premiado pelo Instituto Paulo Gontijo</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>04/11/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/cicloespastro.html" target="_blank"><b>Ciclo de Cursos Especiais em Astronomia acontece até sexta-feira </b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>30/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/danca.html" target="_blank"><b>Dança dos Continentes em ritmo de samba</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>24/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/ciencia.html" target="_blank"><b>Observatório Nacional discute a Natureza da Luz na Semana Nacional de Ciência e Tecnologia</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>16/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/semana.html" target="_blank"><b>ON leva experimentos ao Parque Madureira a partir de sexta-feira</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>14/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/horario.html" target="_blank"><b>Horário de verão 2014/2015 começa dia 19 de outubro e terá uma semana a mais</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>09/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/Science.html" target="_blank"><b>Artigo na Science, com autor do Observatório Nacional, explica
# observação inédita de fenômeno previsto no modelo do Big Bang</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>09/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/magica.html" target="_blank"><b>Observatório Nacional vai usar mágica para falar de astronomia na Semana Nacional de Ciência e Tecnologia</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>07/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/eclipse.html" target="_blank"><b>Quarta-feira começará com eclipse total da Lua</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>06/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/pg-coge.html" target="_blank"><b>Geofísica do ON inscreve para pós-graduação</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>02/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/pesq.html" target="_blank"><b>Ex-aluno de doutorado do ON é premiado pela Capes como melhor tese em Física/Astronomia</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>02/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/pedido.html" target="_blank"><b>Observatório Nacional deposita 4 pedidos de registros de software</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>02/10/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/pg.html" target="_blank"><b>Astronomia do ON inscreve para pós-graduação</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>19/09/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/primavera.html" target="_blank"><b>Primavera começa dia 22 de setembro, às 23h29</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>16/09/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/cetem.html" target="_blank"><b>Semana Nacional de Ciência e Tecnologia</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>10/09/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/itacuruba.html" target="_blank"><b>ON recebe visitantes no OASI e realiza o 3º Evento de Astronomia</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>08/09/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/debatevidaforaterra.html" target="_blank"><b>Observatório Nacional debate a vida fora da Terra </b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>05/09/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/igmas.html" target="_blank"><b>ON instala primeira Estação Brasileira de Monitoramento do Sistema de Posicionamento por Satélites Chinês BEIDOU</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>26/08/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/expedicao.html" target="_blank"><b>Pesquisador do ON integrará expedição na costa australiana</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>21/08/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/pesquisa.html" target="_blank"><b>Pesquisa em arqueomagnetismo obtém apoio financeiro da CAPES</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>20/08/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/alma.html" target="_blank"><b>Pesquisadores reunidos no ON debatem utilização do telescópio ALMA</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>15/08/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/olimpiada.html" target="_blank"><b>Brasil ganha medalha de prata em Olimpíada Internacional de Astronomia e Astrofísica</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font><br>08/08/2014<img src="imagens/seta.gif" width="10" height="9" border="0"><br><a href="http://www.on.br/conteudo/noticias/hubble.html" target="_blank"><b>Telescópio espacial Hubble será usado na observação de anéis descobertos por pesquisadores do ON</b></a><br>
# 			<font color="#CFCFCF">----------------------------------------</font>
# <!--------------------------------------------------------------Notícias------------------------------------------------->
# </div>
#
# <div style="font-family: Times; color: white;font-size: 13pt; background-color: #9FB6CD; margin-top: 4%"><center>Pós-Graduação & Inic. Científica</center></div>
#
# <div style="font-family: Arial; font-size: 12pt; background-color: #B9D3EE; overflow: auto; height: 51.6%">
#
#
# <strong>ASTRONOMIA E ASTROFÍSICA</strong></a><br><br>
#
# <!--
# Mestrado:<!a target="_new" href="http://www.on.br/conteudo/dppg_e_iniciacao/dppg/neweb_astro/conteudo/form_inscricao.html">Inscrições abertas</a><br>
#
# Doutorado: <!a target="_new" href="http://www.on.br/conteudo/dppg_e_iniciacao/dppg/neweb_astro/">Inscrições Encerradas</a><br>
# -->
# Mestrado:&nbsp;&nbsp;&nbsp;<!--a target="_blank" href="http://www.on.br/conteudo/dppg_e_iniciacao/dppg/neweb_astro/conteudo/docs/edital2015A.pdf"-->Inscrições Encerradas<br>
#
# Doutorado:&nbsp;<!--a target="_blank" href="http://www.on.br/conteudo/dppg_e_iniciacao/dppg/neweb_astro/conteudo/docs/edital2015A.pdf"-->Inscrições Encerradas<br>
#
# <a target="_new" href="http://www.on.br/dppg-astronomia/index.html"> <i> Calendário</i></a><br><br>
#
#
# <!-- GEO -->
#
# <a target="_new" href="http://www.on.br/conteudo/dppg_e_iniciacao/dppg/neweb_geo/">
# <strong>GEOFÍSICA</strong></a><br><br>
#
#
# <!--
# Mestrado: <!a target="_new" href="http://www.on.br/conteudo/dppg_e_iniciacao/dppg/neweb_geo/conteudo/form_inscricao.html"><u>Inscrições abertas</u></a><br>
# -->
#
# Mestrado:&nbsp;&nbsp;&nbsp;<!--A  href="http://www.on.br/conteudo/noticias/Edital_Processo-Selecao_2015_1.pdf" target="_blank"-->Inscrições Encerradas<br>
# Doutorado:&nbsp;<!--a target="_blank" href="http://www.on.br/conteudo/noticias/Edital_Processo-Selecao_2015_1.pdf"--> Inscrições Encerradas<br>
#
#
# <a target="_new" href="http://www.on.br/conteudo/dppg_e_iniciacao/dppg/neweb_geo/conteudo/calendario_2014.html"> <i> Calendário</i></a><br><br>
#
#
#
#
# <!-- PIBIC -->
#
# <br>
# <!--<a target="_new" href="http://staff.on.br/pibic/">-->
#
#
# <a target="_new" href="http://www.on.br/conteudo/index_pibic.php">
# <strong>Iniciação Científica - PIBIC
# </strong></a><br><br>
#
# <a target="_new" href="http://www.on.br/conteudo/index_pibic.php">
#
# Convocatória Bolsas IC Agosto/2014 - Julho/2015
# <!--Não há bolsas disponíveis--></a>
#
#
# </div>
# <!--------------------------------------------------------------------------------------------------------------->
# </div>
#
#
#
# <!--Div da direita-->
# <div id="33" style="height: 80%; width: 25%;font-size: 11pt; background-color: #FF0000; margin-right: 2%; float: right">
# <div style="font-family: Times; color: white;font-size: 13pt; background-color: #9FB6CD"><center>Congressos e Eventos</center></div>
# <!--Div Titulo-->
#
#
# </div>
#
# <!--Div da esquerda abaixo linha-->
# <div id="32" style="font-family: Times; color: white;font-size: 13pt; left: 2%; top: 50%; width: 68.5%; background-color: #9FB6CD; margin-left: 2%; margin-top: 1.5%; float: left"><center>Projetos Internacionais</center>
# </div>
#
# <!--Div da esquerda abaixo esquerda -->
# <div id="31" style="width: 28%; height: 20%; background-color: #FF0000; margin-left: 2%; margin-top: 1.5%; float: left">
# <div style="font-family: Times; color: white;font-size: 13pt; background-color: #9FB6CD"><center>Convênios</center></div>
# </div>
#
# <!--Div da esquerda abaixo centro -->
# <div id="31" style="font-size: 11pt; width: 39%; height: 20%; background-color: #FF0000; margin-left: 1.5%; margin-top: 1.5%; float: left"><div style="font-family: Times; color: white;font-size: 13pt; background-color: #9FB6CD"><center>ON na Mídia</center></div>
# </div></div>
#
# </div> <!--Div final-->
